# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('merged_matches.csv')

# %% [markdown]
# # Dealing with nulls and other changes

# %%
data.head()
# Out:
#   tourney_id            tourney_name surface  draw_size tourney_level  \
# 0  1970-9290  Australian Round Robin   Grass          5             A
# 1  1970-9290  Australian Round Robin   Grass          5             A
# 2  1970-9290  Australian Round Robin   Grass          5             A
# 3  1970-9290  Australian Round Robin   Grass          5             A
# 4  1970-9290  Australian Round Robin   Grass          5             A
#
#    tourney_date  match_num  winner_id  winner_seed winner_entry  ... l_1stIn  \
# 0      19700104        291     100100          NaN          NaN  ...     NaN
# 1      19700104        292     100087          NaN          NaN  ...     NaN
# 2      19700104        293     100037          NaN          NaN  ...     NaN
# 3      19700104        294     100087          NaN          NaN  ...     NaN
# 4      19700104        295     100084          NaN          NaN  ...     NaN
#
#   l_1stWon  l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank  \
# ...

# %%
data.isnull().sum()
# Out:
# tourney_id                 0
# tourney_name               0
# surface                 1220
# draw_size                  0
# tourney_level              0
# tourney_date               0
# match_num                  0
# winner_id                  0
# winner_seed           100183
# winner_entry          153471
# winner_name                0
# winner_hand                2
# winner_ht               9884
# winner_ioc                 7
# winner_age               650
# loser_id                   0
# loser_seed            134397
# loser_entry           141844
# loser_name                 0
# loser_hand                 4
# loser_ht               18362
# loser_ioc                 34
# loser_age               2601
# score                      6
# best_of                    0
# round                      0
# minutes                78979
# w_ace                  76293
# w_df                   76294
# w_svpt                 76294
# w_1stIn                76294
# w_1stWon               76294
# ...

# %%
data[data['tourney_date']>19920101].isnull().sum()
# Out:
# tourney_id                0
# tourney_name              0
# surface                   0
# draw_size                 0
# tourney_level             0
# tourney_date              0
# match_num                 0
# winner_id                 0
# winner_seed           51060
# winner_entry          79850
# winner_name               0
# winner_hand               0
# winner_ht               271
# winner_ioc                0
# winner_age                0
# loser_id                  0
# loser_seed            69607
# loser_entry           71780
# loser_name                0
# loser_hand                0
# loser_ht               1016
# loser_ioc                 0
# loser_age                 9
# score                     0
# best_of                   0
# round                     0
# minutes                4332
# w_ace                  1642
# w_df                   1642
# w_svpt                 1642
# w_1stIn                1642
# w_1stWon               1642
# w_2ndWon               1642
# ...

# %% [markdown]
# ## Surface

# %%
data['surface'].unique()
# Out:
# array(['Grass', 'Hard', 'Carpet', 'Clay', nan], dtype=object)

# %%
data[data['surface'].isnull()][['tourney_id','tourney_name','tourney_level','tourney_date','draw_size']].drop_duplicates()
# Out:
#       tourney_id                 tourney_name tourney_level  tourney_date  \
# 1249   1970-2063               Casablanca WCT             A      19700607
# 3303   1971-2058                     New York             A      19710214
# 5323   1971-2044                   Quebec WCT             A      19710801
# 6155   1971-2048                Vancouver WCT             A      19711010
# 6775   1972-2061                   Des Moines             A      19720206
# 6776   1972-2062                  Kansas City             A      19720206
# 6864   1972-2057                  Los Angeles             A      19720214
# 6977   1972-2058                     New York             A      19720228
# 7418   1972-2044                   Quebec WCT             A      19720416
# 8643   1972-2051                   Tanglewood             A      19720730
# 9217   1972-2052                 Montreal WCT             A      19720917
# 9218    1972-654                   Sacramento             A      19720917
# ...

# %%
#filling nulls manually
data['surface'] = np.where(data['tourney_id']=='1970-2063', 'Clay', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1972-2062', 'Hard', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1972-2057', 'Hard', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1972-2051', 'Clay', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1972-2052', 'Hard', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1972-654', 'Hard', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1972-2043', 'Hard', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1972-2053', 'Hard', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1973-2038', 'Hard', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1973-2051', 'Clay', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1973-2043', 'Hard', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1973-2045', 'Clay', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1973-2046', 'Clay', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1974-2037', 'Hard', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1974-2038', 'Hard', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1974-2039', 'Hard', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1974-329', 'Hard', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1974-2029', 'Grass', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1974-2031', 'Clay', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1974-428', 'Hard', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1974-2033', 'Hard', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1975-2021', 'Hard', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1975-2027', 'Clay', data['surface'])
data['surface'] = np.where(data['tourney_id']=='1977-2059', 'Hard', data['surface'])
data['surface'] = data['surface'].fillna('Carpet')

# %% [markdown]
# ## draw size

# %%
data['draw_size'].unique()
# Out:
# array([  5,  64,  32,  16,   8, 128,   9,   6,   4,   7,  48,  24,  10,
#         12,   2,  96,  56,  28,  18], dtype=int64)

# %%
data[data['draw_size']==18]
# Out:
#        tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 167438  2023-9900   United Cup    Hard         18             A      20230102
# 167439  2023-9900   United Cup    Hard         18             A      20230102
# 167440  2023-9900   United Cup    Hard         18             A      20230102
# 167441  2023-9900   United Cup    Hard         18             A      20230102
# 167442  2023-9900   United Cup    Hard         18             A      20230102
# 167443  2023-9900   United Cup    Hard         18             A      20230102
# 167444  2023-9900   United Cup    Hard         18             A      20230102
# 167445  2023-9900   United Cup    Hard         18             A      20230102
# 167446  2023-9900   United Cup    Hard         18             A      20230102
# 167447  2023-9900   United Cup    Hard         18             A      20230102
# 167448  2023-9900   United Cup    Hard         18             A      20230102
# ...

# %% [markdown]
# ## tourney level

# %%
data['tourney_level'].unique()
#'G' = Grand Slams, 'M' = Masters 1000s, 'A' = other tour-level events, 'F' = Tour finals and other season-ending events
# Out:
# array(['A', 'G', 'M', 'F'], dtype=object)

# %%
data['tourney_level'] = data['tourney_level'].replace('A', 'Other')
data['tourney_level'] = data['tourney_level'].replace('G', 'Grand Slam')
data['tourney_level'] = data['tourney_level'].replace('M', 'Masters 1000')
data['tourney_level'] = data['tourney_level'].replace('F', 'Season-ending events')

# %% [markdown]
# ## winner/loser name

# %%
data[data['winner_id']==199999]
# Out:
#       tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 2315    1970-414      Hamburg    Clay         64         Other      19700817
# 15769   1974-720     Surbiton   Grass         32         Other      19740601
#
#        match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 2315           2     199999          NaN          NaN  ...     NaN      NaN
# 15769        278     199999          NaN          NaN  ...     NaN      NaN
#
#        l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# 2315        NaN     NaN        NaN        NaN          NaN                NaN
# 15769       NaN     NaN        NaN        NaN          NaN                NaN
#
#       loser_rank loser_rank_points
# 2315         NaN               NaN
# 15769        NaN               NaN
#
# [2 rows x 49 columns]

# %%
data[data['loser_id']==199999]
# Out:
#       tourney_id    tourney_name surface  draw_size tourney_level  \
# 719     1970-410     Monte Carlo    Clay         64         Other
# 1169   1970-8025      Manchester   Grass          8         Other
# 1170   1970-8025      Manchester   Grass          8         Other
# 1172   1970-8025      Manchester   Grass          8         Other
# 1651    1970-661      Dusseldorf    Clay         32         Other
# 1673    1970-661      Dusseldorf    Clay         32         Other
# 1677    1970-661      Dusseldorf    Clay         32         Other
# 1679    1970-661      Dusseldorf    Clay         32         Other
# 2128    1970-317       Hilversum    Hard         64         Other
# 2137    1970-317       Hilversum    Hard         64         Other
# 2141    1970-317       Hilversum    Hard         64         Other
# 2339    1970-414         Hamburg    Clay         64         Other
# 2755    1970-425       Barcelona    Clay         64         Other
# ...

# %%
#removing matches with not known players
data = data[data['winner_id']!=199999]
data = data[data['loser_id']!=199999]

# %% [markdown]
# ## winner/loser hand?

# %%
data['winner_hand'].unique()
# Out:
# array(['L', 'R', 'U', nan, 'A'], dtype=object)

# %%
data[data['winner_hand'].isnull()]
# Out:
#      tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 1664  1970-2029       Dublin   Grass         32         Other      19700706
# 1678  1970-2029       Dublin   Grass         32         Other      19700706
#
#       match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 1664        277     207073          NaN          NaN  ...     NaN      NaN
# 1678        284     207077          NaN          NaN  ...     NaN      NaN
#
#       l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# 1664       NaN     NaN        NaN        NaN          NaN                NaN
# 1678       NaN     NaN        NaN        NaN          NaN                NaN
#
#      loser_rank loser_rank_points
# 1664        NaN               NaN
# 1678        NaN               NaN
#
# [2 rows x 49 columns]

# %%
 data[data['loser_hand'].isnull()]
# Out:
#      tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 660   1970-9204     Kingston    Hard         32         Other      19700406
# 1686  1970-2029       Dublin   Grass         32         Other      19700706
# 1690  1970-2029       Dublin   Grass         32         Other      19700706
# 2256   1970-319   Kitzbuehel    Clay         64         Other      19700809
#
#       match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 660         285     100110          NaN          NaN  ...     NaN      NaN
# 1686        288     100060          NaN          NaN  ...     NaN      NaN
# 1690        290     100029          NaN          NaN  ...     NaN      NaN
# 2256        269     100139          NaN          NaN  ...     NaN      NaN
#
#       l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# 660        NaN     NaN        NaN        NaN          NaN                NaN
# ...

# %%
#replacing nulls with R
data['loser_hand'] = data['loser_hand'].fillna('R')
data['winner_hand'] = data['winner_hand'].fillna('R')

# %%
data[data['winner_hand']=='A']['winner_name'].unique()
# Out:
# array(['Roland Stadler', 'Roberto Arguello', 'Luke Jensen'], dtype=object)

# %%
data['loser_hand'] = data['loser_hand'].replace('A', 'R')
data['winner_hand'] = data['winner_hand'].replace('A', 'R')

# %%
data[data['winner_hand']=='U']['winner_name'].unique(), len(data[data['winner_hand']=='U']['winner_name'].unique())
# Out:
# (array(['Richard Rae', 'Peter Becroft', 'Charles Caudle',
#         'Lewis Sylvester', 'Lex Hester', 'Jim Bochte', 'John Solow',
#         'Jim Oescher', 'Sven Ginman', 'Luis Augusto Garcia',
#         'Frank McDonald', 'Compton Russell', 'Leo Rolle',
#         'A Rodney Mandelstam', 'Stepan Koudelka', 'Lothar Pawlik',
#         'Rob Simpson', 'Simon Partridge', 'Lindsay Murphy', 'Steve Fiske',
#         'Ian Beverly', 'Mel Baleson', 'C Wijono', 'David Segal',
#         'Gerry Perry', 'Richard Howes', 'John Williams', 'R Walker',
#         'P Scott', 'P Mortoire', 'Dennis Matthews', 'S Joseph', 'R Jenkin',
#         'A J Gould', 'R W Davies', 'C J Bendall', 'A G Barker',
#         'Harry Sheridan', 'Peter Jackson', 'Patrice Wiman', 'L B Taylor',
#         'Geoff Stubbs', 'Jimmy Moore', 'Pieter Soeters', 'Fred Hemmes',
#         'Dieter Schultheiss', 'Peter Popovic', 'Jean Pierre Loizeau',
#         'John Lockington', 'Hansjorg Elzer', 'Uwe Gottschalk',
# ...

# %%
data[data['loser_hand']=='U']['loser_name'].unique(), len(data[data['loser_hand']=='U']['loser_name'].unique())
# Out:
# (array(['John Stephens', 'Paul Thompson', 'Ian Baudinet', ...,
#         'Bu Yunchaokete', 'Alexander Blockx', 'Billy Harris'], dtype=object),
#  1083)

# %%
#?
data['loser_hand'] = data['loser_hand'].replace('U', 'R')
data['winner_hand'] = data['winner_hand'].replace('U', 'R')

# %% [markdown]
# ## winner/loser height?

# %%
data[(data['winner_ht'].isnull()) & (data['tourney_date']>19920101)]['winner_name'].unique(), len(data[(data['winner_ht'].isnull()) & (data['tourney_date']>19920101)]['winner_name'].unique())
# Out:
# (array(['Milen Velev', 'Ralph Kok', 'Hideki Kaneko', 'Han Cheol Shin',
#         'Nicolas Kischkewitz', 'Ryuso Tsujino', 'Axel Finnberg',
#         'Juan Luis Tati Rascon', 'Bill Barber', 'Gilles Bastie',
#         'Mario Rincon', 'Howard Joffe', 'Kotaro Miyachi', 'Colin Beecher',
#         'Alexandre Strambini', 'Daniele Balducci', 'Nir Welgreen',
#         'Filippo Veglio', 'Federico Dondo', 'Marcus Hilpert', 'Jordi Mas',
#         'Igor Kornienko', 'Solon Peppas', 'Dejan Petrovic', 'Kalle Flygt',
#         'Johan Ortegren', 'Lee Childs', 'Jonas Froberg',
#         'Takahiro Terachi', 'Mounir El Aarej', 'Thomas Blake',
#         'Maximilian Abel', 'Diogo Rocha', 'Ian Flanagan', 'Matias Boeker',
#         'Hao Lu', 'Ben Qiang Zhu', 'Todd Widom', 'Peng Sun', 'Yu Jr Wang',
#         'Mohammad Ghareeb', 'Slimane Saoudi', 'Stefano Ianni',
#         'Luka Gregorc', 'James Auckland', 'Gabriel Trujillo Soler',
#         'Ervin Eleskovic', 'Martin Slanar', 'Karlis Lejnieks',
# ...

# %%
data[(data['loser_ht'].isnull()) & (data['tourney_date']>19920101)]['loser_name'].unique(), len(data[(data['loser_ht'].isnull()) & (data['tourney_date']>19920101)]['loser_name'].unique())
# Out:
# (array(['Juan Pablo Etchecoin', 'Toshihisa Tsuchihashi', 'Ryuso Tsujino',
#         'Hidehiko Tanizawa', 'Kentaro Masuda', 'Michael Walker',
#         'Hyeong Keun Song', 'Seung Ho Ji', 'Jae Sik Kim',
#         'Francesco Michelotti', 'Jordi Mas', 'Alexander Windisch',
#         'Srdan Muskatirovic', 'Owen Casey', 'Dick Bosse',
#         'Roberto Alvarez', 'Thierry Van Den Daele', 'Jorg Schors',
#         'Tasos Bavelas', 'Andreas Fikas', 'Talito Corrales', 'Milen Velev',
#         'Gil Kovalski', 'Hideki Kaneko', 'Cheng Fong Chang',
#         'Chih Jung Chen', 'Yu Hui Lien', 'Fabien Cousin',
#         'Thomas Prerovsky', 'Andrew Mclean', 'Ashley Naumann',
#         'Juan Luis Tati Rascon', 'Michael Shyjan', 'Ralph Kok',
#         'Christian Camradt', 'Mohamed Ridaoui', 'Han Cheol Shin',
#         'Guillaume Marx', 'Rene Nicklisch', 'Sean Cole',
#         'Patrik Langvardt', 'Sergio Gomez Barrio', 'John Roddick',
#         'Nicolas Kischkewitz', 'Martin Schaffl', 'Tony Bujan',
# ...

# %%
data[['winner_ht', 'loser_ht']].mean()
# Out:
# winner_ht    184.575372
# loser_ht     184.305956
# dtype: float64

# %%
#replacing height with means
data['winner_ht'] = data['winner_ht'].fillna(184.575372)
data['loser_ht'] = data['loser_ht'].fillna(184.305956)

# %% [markdown]
# ## winner/loser age

# %%
data[(data['winner_age'].isnull()) & (data['tourney_date']>19920101)]['winner_name'].unique(), len(data[(data['winner_age'].isnull()) & (data['tourney_date']>19920101)]['winner_name'].unique())
# Out:
# (array([], dtype=object), 0)

# %%
data[(data['loser_age'].isnull()) & (data['tourney_date']>19920101)]['loser_name'].unique(), len(data[(data['loser_age'].isnull()) & (data['tourney_date']>19920101)]['loser_name'].unique())
# Out:
# (array(['Juan Pablo Etchecoin', 'Talito Corrales', 'Gil Kovalski',
#         'Marco Cacopardo', 'Dan Cantwell', 'Manas Dhamne', 'Liam Krall',
#         'Yi Zhou'], dtype=object),
#  8)

# %%
data[data['loser_name']=='Yi Zhou']
# Out:
#        tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 169718  2023-9164       Zhuhai    Hard         32         Other      20230920
# 169798  2023-0747      Beijing    Hard         32         Other      20230927
#
#         match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 169718        275     106426          NaN          NaN  ...    44.0     30.0
# 169798        276     200221          NaN          NaN  ...    44.0     22.0
#
#         l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank  \
# 169718      18.0    14.0        2.0        6.0        102.0
# 169798      12.0     8.0        4.0        9.0         25.0
#
#        winner_rank_points loser_rank loser_rank_points
# 169718              596.0      903.0              18.0
# 169798             1435.0      905.0              18.0
#
# [2 rows x 49 columns]

# %%
data.loc[169718, 'loser_age'] = 18.5
data.loc[169798, 'loser_age'] = 18.5

# %%
data[data['loser_name']=='Liam Krall']
# Out:
#        tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 167729  2023-0424       Dallas    Hard         32         Other      20230206
#
#         match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 167729        272     105430          NaN          NaN  ...    49.0     37.0
#
#         l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank  \
# 167729      14.0    13.0        2.0        5.0        123.0
#
#        winner_rank_points loser_rank loser_rank_points
# 167729              443.0        NaN               NaN
#
# [1 rows x 49 columns]

# %%
data.loc[167729, 'loser_age'] = 20.7

# %%
data[data['loser_name']=='Manas Dhamne']
# Out:
#        tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 167485  2023-0891         Pune    Hard         32         Other      20230102
#
#         match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 167485        276     111581          NaN          NaN  ...    37.0     21.0
#
#         l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank  \
# 167485      10.0     9.0        6.0       10.0        113.0
#
#        winner_rank_points loser_rank loser_rank_points
# 167485              507.0        NaN               NaN
#
# [1 rows x 49 columns]

# %%
data.loc[167485, 'loser_age'] = 15

# %%
data[['winner_age', 'loser_age']].mean()
# Out:
# winner_age    25.737354
# loser_age     25.826334
# dtype: float64

# %%
data['loser_age'] = data['loser_age'].fillna(25.8)

# %% [markdown]
# ## Score

# %%
data[data['score'].isnull()]
# Out:
#       tourney_id     tourney_name surface  draw_size tourney_level  \
# 62      1970-580  Australian Open   Grass         64    Grand Slam
# 36652   1979-353            Quito    Clay         32         Other
# 40983   1980-338   Sydney Outdoor   Grass         64         Other
# 41209   1981-345    Monterrey WCT  Carpet         32         Other
# 42218   1981-310         Florence    Clay         32         Other
# 44403   1981-430          Wembley  Carpet         32         Other
#
#        tourney_date  match_num  winner_id  winner_seed winner_entry  ...  \
# 62         19700119         16     100041          NaN          NaN  ...
# 36652      19791105         12     100417          4.0          NaN  ...
# 40983      19801215         28     100574          NaN          NaN  ...
# 41209      19810119         24     100342          2.0          NaN  ...
# 42218      19810511         14     100185          NaN          NaN  ...
# ...

# %%
data.loc[62, 'score'] = 'W/O'
data.loc[36652, 'score'] = '6-2 6-2'
data.loc[40983, 'score'] = '6-3 6-3'
data.loc[41209, 'score'] = 'W/O'
data.loc[42218, 'score'] = 'W/O'
data.loc[44403, 'score'] = 'W/O'

# %%
# RET - retire
# W/O - walkover
# DEF - disqualification
# ABD - retire
data.loc[data['score'].str.contains('RET'), 'score']='RET' 
data.loc[data['score'].str.contains('DEF'), 'score']='DEF'
data.loc[data['score'].str.contains('ABD'), 'score']='RET'
data.loc[data['score'].str.contains('Def'), 'score']='DEF'

# %%
# remove tie breaks scores
data['score'] = data['score'].str.replace(r'\([1-9][0-9]\)', '', regex=True)
data['score'] = data['score'].str.replace(r'\([0-9]\)', '', regex=True)
data['score'] = data['score'].str.replace(r'\[.+\]', '1-0', regex=True)

# %%
data['score'].unique(), len(data['score'].unique())
# Out:
# (array(['6-4 6-1', '6-2 6-3', '13-11', ..., '4-1 4-2 4-2',
#         '4-2 3-4 4-2 4-3', '3-4 4-1 4-2 3-4 4-1'], dtype=object),
#  10815)

# %%
print(list(data['score'].unique()))
# Out:
# ['6-4 6-1', '6-2 6-3', '13-11', '10-8', '7-5 3-6 6-3', '8-6 6-3', '6-3 6-4', '3-6 6-3 6-4', '6-4 3-6 6-2', '5-7 7-5 7-5', '6-3 6-4 3-6 4-6 6-1', '12-10 7-5 8-6', '6-2 6-4 6-3', '6-4 6-4 6-0', '3-6 10-8 10-8 6-8 8-6', 'W/O', '9-7 3-6 9-7 6-3', '6-4 6-2 4-6 6-3', '12-10 6-3 6-4', '7-5 7-5 6-1', '12-10 6-3 8-6', '10-8 4-6 6-2 7-5', '6-3 7-9 6-2 8-6', '6-3 6-4 6-3', '6-2 6-4 6-1', '6-3 6-3 10-8', '0-6 6-4 13-11 6-3', '6-4 3-6 6-4 6-2', '13-11 6-4 3-6 6-3', '3-6 6-3 10-8 8-6', '6-4 6-4', '14-12 13-11', '6-1 6-2', '6-2 6-4', '9-7 12-10', '6-3 2-6 6-3', '6-4 6-2', '3-6 4-6 7-5 6-1 19-17', '3-6 16-14 6-1 8-10 6-4', '9-7 15-13 4-6 6-2', '6-3 6-3 6-2', '11-9 12-14 12-10 6-3', '6-3 6-2 7-5', 'RET', '6-4 12-10', '7-5 6-4', '8-6 6-4', '6-4 10-8 12-10', '9-7 0-6 6-4', '6-1 6-1', '6-3 8-10 6-4', '6-4 3-6 6-3', '6-4 7-5', '17-19 6-3 6-2', '4-6 9-7 6-3', '6-4 6-3', '8-6 11-9 6-4', '2-6 6-3 2-6 6-0 6-4', '6-4 6-3 6-4', '6-1 6-3 6-1', '6-4 6-2 7-5', '6-1 8-6 6-4', '6-3 13-11 9-11 3-6 6-1', '8-6 6-4 1-6
# ...

# %%
data[data['score']=='UNK'][['tourney_id','tourney_name','winner_name','loser_name']]
# Out:
#       tourney_id    tourney_name           winner_name         loser_name
# 1659    1970-661      Dusseldorf           Alex Kurucz       Jost Remmert
# 1661    1970-661      Dusseldorf         Attila Korpas      Peter Pokorny
# 1663    1970-661      Dusseldorf     Francois Jauffret         Bernd Kube
# 1667    1970-661      Dusseldorf     Jurgen Fassbender   Matthias Mauritz
# 1669    1970-661      Dusseldorf         Eric Drossart   Christian Pieper
# 1691    1970-661      Dusseldorf         Daniel Contet        Ingo Buding
# 1693    1970-661      Dusseldorf         Istvan Gulyas  Jurgen Fassbender
# 1695    1970-661      Dusseldorf       Wilhelm Bungert        Peter Szoke
# 2265    1970-319      Kitzbuehel     Francois Jauffret         Onny Parun
# 3767    1971-681       Miami WCT         Andres Gimeno      Brian Fairlie
# 4157    1971-818     Chicago WCT         Torben Ulrich          Rod Laver
# 4168    1971-818     Chicago WCT             Tom Okker      Brian Fairlie
# ...

# %%
data.loc[58407, 'score'] = '6-4 6-4'

# %%
data = data[(data['score']!='RET') & (data['score']!='DEF') & (data['score']!='W/O') & (data['score']!='UNK')]

# %% [markdown]
# ## best of

# %%
data['best_of'].unique()
# Out:
# array([3, 5, 1], dtype=int64)

# %%
data[data['best_of']==1]
# Out:
#      tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 1008   1970-412      Atlanta    Hard         16         Other      19700506
# 4084   1971-389       Denver  Carpet          8         Other      19710421
# 4085   1971-389       Denver  Carpet          8         Other      19710421
# 4086   1971-389       Denver  Carpet          8         Other      19710421
# 4087   1971-389       Denver  Carpet          8         Other      19710421
# 4088   1971-389       Denver  Carpet          8         Other      19710421
# 4089   1971-389       Denver  Carpet          8         Other      19710421
# 4090   1971-389       Denver  Carpet          8         Other      19710421
# 4091   1971-389       Denver  Carpet          8         Other      19710421
# 4092   1971-389       Denver  Carpet          8         Other      19710421
# 4093   1971-389       Denver  Carpet          8         Other      19710421
# ...

# %% [markdown]
# ## Round

# %%
data['round'].unique()
# Out:
# array(['RR', 'F', 'R64', 'R32', 'R16', 'QF', 'SF', 'BR', 'R128', 'ER'],
#       dtype=object)

# %%
data[data['round']=='ER']
# Out:
#        tourney_id  tourney_name surface  draw_size tourney_level  \
# 125811   2007-339      Adelaide    Hard         32         Other
# 125818   2007-339      Adelaide    Hard         32         Other
# 125819   2007-339      Adelaide    Hard         32         Other
# 125823   2007-339      Adelaide    Hard         32         Other
# 125824   2007-339      Adelaide    Hard         32         Other
# 125825   2007-339      Adelaide    Hard         32         Other
# 125827   2007-339      Adelaide    Hard         32         Other
# 125843   2007-339      Adelaide    Hard         32         Other
# 126037   2007-499  Delray Beach    Hard         32         Other
# 126041   2007-499  Delray Beach    Hard         32         Other
# 126047   2007-499  Delray Beach    Hard         32         Other
# 126050   2007-499  Delray Beach    Hard         32         Other
# 126054   2007-499  Delray Beach    Hard         32         Other
# ...

# %%
data['round'] = data['round'].replace('ER', 'RR')
data['round'] = data['round'].replace('BR', 'SF')

# %% [markdown]
# ## match statistics

# %%
data[data['tourney_date']>=19910101].isnull().sum()
# Out:
# tourney_id                0
# tourney_name              0
# surface                   0
# draw_size                 0
# tourney_level             0
# tourney_date              0
# match_num                 0
# winner_id                 0
# winner_seed           51154
# winner_entry          80287
# winner_name               0
# winner_hand               0
# winner_ht                 0
# winner_ioc                0
# winner_age                0
# loser_id                  0
# loser_seed            70230
# loser_entry           71880
# loser_name                0
# loser_hand                0
# loser_ht                  0
# loser_ioc                 0
# loser_age                 0
# score                     0
# best_of                   0
# round                     0
# minutes                4046
# w_ace                  1360
# w_df                   1360
# w_svpt                 1360
# w_1stIn                1360
# w_1stWon               1360
# w_2ndWon               1360
# ...

# %%
data[(data['w_ace'].isnull()) & (data['tourney_date']>=19910101)]
# Out:
#        tourney_id          tourney_name surface  draw_size tourney_level  \
# 75113    1991-404  Indian Wells Masters    Hard         56  Masters 1000
# 75367    1991-329         Tokyo Outdoor    Hard         56         Other
# 75406    1991-425             Barcelona    Clay         56         Other
# 75534    1991-410   Monte Carlo Masters    Clay         56  Masters 1000
# 75787    1991-416          Rome Masters    Clay         64  Masters 1000
# ...           ...                   ...     ...        ...           ...
# 167008  2022-9210             Laver Cup    Hard          8         Other
# 167009  2022-9210             Laver Cup    Hard          8         Other
# 167010  2022-9210             Laver Cup    Hard          8         Other
# 167011  2022-9210             Laver Cup    Hard          8         Other
# 167012  2022-9210             Laver Cup    Hard          8         Other
#
#         tourney_date  match_num  winner_id  winner_seed winner_entry  ...  \
# ...

# %%
data[(data['w_ace'].isnull()) & (data['tourney_date']>=19910101)].groupby(['tourney_id', 'tourney_name']).count()
# Out:
#                            surface  draw_size  tourney_level  tourney_date  \
# tourney_id tourney_name
# 1991-311   Queen's Club          2          2              2             2
# 1991-312   Bologna               1          1              1             1
# 1991-314   Gstaad                1          1              1             1
# 1991-317   Hilversum             1          1              1             1
# 1991-329   Tokyo Outdoor         1          1              1             1
# ...                            ...        ...            ...           ...
# 2019-9210  Laver Cup             9          9              9             9
# 2021-0096  Tokyo Olympics       64         64             64            64
# 2021-0418  Washington            1          1              1             1
# 2021-9210  Laver Cup             6          6              6             6
# 2022-9210  Laver Cup             8          8              8             8
#
# ...

# %%
#records with no statistics will not be used to calculate historical performance

# %% [markdown]
# ## Rank

# %%
data[(data['winner_rank'].isnull()) & (data['tourney_date']>=19920101)]
# Out:
#        tourney_id     tourney_name surface  draw_size tourney_level  \
# 78335    1992-401     Philadelphia  Carpet         48         Other
# 78680    1992-456        Singapore    Hard         32         Other
# 78765    1992-329    Tokyo Outdoor    Hard         56         Other
# 78863    1992-336        Hong Kong    Hard         32         Other
# 79661    1992-540        Wimbledon   Grass        128    Grand Slam
# ...           ...              ...     ...        ...           ...
# 161519   2020-560          Us Open    Hard        128    Grand Slam
# 167632   2023-580  Australian Open    Hard        128    Grand Slam
# 168881  2023-0440  s Hertogenbosch   Grass         32         Other
# 169174  2023-0315          Newport   Grass         32         Other
# 169207  2023-0315          Newport   Grass         32         Other
#
#         tourney_date  match_num  winner_id  winner_seed winner_entry  ...  \
# 78335       19920217         16     101687          NaN           WC  ...
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
data[(data['winner_rank'].isnull()) & (data['tourney_date']>=19920101)].groupby(['winner_name', 'tourney_date']).count().sort_values(by=['winner_name', 'tourney_date'])
# Out:
#                                   tourney_id  tourney_name  surface  \
# winner_name         tourney_date
# Andreas Vinciguerra 20050704               1             1        1
# Andrey Kuznetsov    20200831               1             1        1
# Bent Ove Pedersen   19930104               1             1        1
# Chris Woodruff      19990208               1             1        1
# David Dilucia       19920217               1             1        1
# David Skoch         19930802               1             1        1
# Derrick Rostagno    19950313               1             1        1
# Fabrice Santoro     19981102               1             1        1
# Felix Mantilla      19990208               2             2        2
# Florian Mayer       20150412               1             1        1
# Girts Dzelde        19950313               1             1        1
# Guillermo Coria     20080211               1             1        1
# ...

# %%
data['winner_rank'] = np.where(data['winner_name']=='Martin Damm Sr', 80.0, data['winner_rank'])

# %%
data[(data['loser_rank'].isnull()) & (data['tourney_date']>=19920101)]
# Out:
#        tourney_id          tourney_name surface  draw_size tourney_level  \
# 78230    1992-402               Memphis    Hard         48         Other
# 78367    1992-401          Philadelphia  Carpet         48         Other
# 78633    1992-360            Casablanca    Clay         32         Other
# 78716    1992-456             Singapore    Hard         32         Other
# 78809    1992-329         Tokyo Outdoor    Hard         56         Other
# 78908    1992-336             Hong Kong    Hard         32         Other
# 78958    1992-434                 Seoul    Hard         32         Other
# 78966    1992-434                 Seoul    Hard         32         Other
# 79058    1992-309                Madrid    Clay         32         Other
# 79482    1992-440              Rosmalen   Grass         32         Other
# 79606    1992-306                Genova    Clay         32         Other
# 79716    1992-540             Wimbledon   Grass        128    Grand Slam
# ...

# %%
data[(data['loser_rank'].isnull()) & (data['tourney_date']>=19920101)].groupby(['loser_name', 'tourney_date']).count().sort_values(by=['loser_name', 'tourney_date'])
# Out:
#                                            tourney_id  tourney_name  surface  \
# loser_name                   tourney_date
# Abdul Hamid Makhkamov        19970908               1             1        1
# Abdulla Hajji                20071231               1             1        1
#                              20090105               1             1        1
#                              20100104               1             1        1
# Adam Peterson                19950306               1             1        1
# Adrian Andreev               20180205               1             1        1
#                              20190204               1             1        1
# Akash Wagh                   20060925               1             1        1
# Alastair Gray                20190715               1             1        1
# Alex Kim                     19970714               1             1        1
# Alexandar Lazarov            20190204               1             1        1
# ...

# %%
data['loser_rank'] = np.where(data['loser_name']=='Martin Damm Sr', 80.0, data['loser_rank'])

# %%
data[(data['winner_rank'].isnull()) & (data['loser_rank'].isnull()) & (data['tourney_date']>=19920101)]
# Out:
# Empty DataFrame
# Columns: [tourney_id, tourney_name, surface, draw_size, tourney_level, tourney_date, match_num, winner_id, winner_seed, winner_entry, winner_name, winner_hand, winner_ht, winner_ioc, winner_age, loser_id, loser_seed, loser_entry, loser_name, loser_hand, loser_ht, loser_ioc, loser_age, score, best_of, round, minutes, w_ace, w_df, w_svpt, w_1stIn, w_1stWon, w_2ndWon, w_SvGms, w_bpSaved, w_bpFaced, l_ace, l_df, l_svpt, l_1stIn, l_1stWon, l_2ndWon, l_SvGms, l_bpSaved, l_bpFaced, winner_rank, winner_rank_points, loser_rank, loser_rank_points]
# Index: []
#
# [0 rows x 49 columns]

# %%
data['loser_rank'].max()
# Out:
# 2159.0

# %%
data['loser_rank'] = data['loser_rank'].fillna(2160.0)
data['winner_rank'] = data['winner_rank'].fillna(2160.0)

# %% [markdown]
# ## dropping columns

# %%
data = data.drop(['match_num', 'winner_seed', 'winner_entry','loser_seed','loser_entry','winner_ioc','loser_ioc','winner_rank_points','loser_rank_points','minutes'], axis=1)

# %%
data.head(5)
# Out:
#   tourney_id            tourney_name surface  draw_size tourney_level  \
# 0  1970-9290  Australian Round Robin   Grass          5         Other
# 1  1970-9290  Australian Round Robin   Grass          5         Other
# 2  1970-9290  Australian Round Robin   Grass          5         Other
# 3  1970-9290  Australian Round Robin   Grass          5         Other
# 4  1970-9290  Australian Round Robin   Grass          5         Other
#
#    tourney_date  winner_id    winner_name winner_hand  winner_ht  ...  l_df  \
# 0      19700104     100100     Tony Roche           L      178.0  ...   NaN
# 1      19700104     100087  John Newcombe           R      183.0  ...   NaN
# 2      19700104     100037   Nikola Pilic           L      191.0  ...   NaN
# 3      19700104     100087  John Newcombe           R      183.0  ...   NaN
# 4      19700104     100084      Tom Okker           R      178.0  ...   NaN
#
#    l_svpt l_1stIn l_1stWon  l_2ndWon  l_SvGms l_bpSaved  l_bpFaced  \
# ...

# %%
data.to_csv('cleaned_data.csv', index=False)
